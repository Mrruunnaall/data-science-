# %%
DATA PROCESSING FOR ASSOCIATION

# %%
# Load the datasetrequired
import pandas as pd

df = pd.read_csv('/content/Online retail.csv')  # Load the dataset in dataframe

df
# Out:
#      shrimp,almonds,avocado,vegetables mix,green grapes,whole weat flour,yams,cottage cheese,energy drink,tomato juice,low fat yogurt,green tea,honey,salad,mineral water,salmon,antioxydant juice,frozen smoothie,spinach,olive oil
# 0                                burgers,meatballs,eggs
# 1                                               chutney
# 2                                        turkey,avocado
# 3     mineral water,milk,energy bar,whole wheat rice...
# 4                                        low fat yogurt
# ...                                                 ...
# 7495                      butter,light mayo,fresh bread
# 7496  burgers,frozen vegetables,eggs,french fries,ma...
# 7497                                            chicken
# 7498                                 escalope,green tea
# 7499    eggs,frozen smoothie,yogurt cake,low fat yogurt
#
# [7500 rows x 1 columns]

# %%
df.head() #Display first five values of dataset
# Out:
#   shrimp,almonds,avocado,vegetables mix,green grapes,whole weat flour,yams,cottage cheese,energy drink,tomato juice,low fat yogurt,green tea,honey,salad,mineral water,salmon,antioxydant juice,frozen smoothie,spinach,olive oil
# 0                             burgers,meatballs,eggs
# 1                                            chutney
# 2                                     turkey,avocado
# 3  mineral water,milk,energy bar,whole wheat rice...
# 4                                     low fat yogurt

# %%
df.tail() #Display last five values of dataset
# Out:
#      shrimp,almonds,avocado,vegetables mix,green grapes,whole weat flour,yams,cottage cheese,energy drink,tomato juice,low fat yogurt,green tea,honey,salad,mineral water,salmon,antioxydant juice,frozen smoothie,spinach,olive oil
# 7495                      butter,light mayo,fresh bread
# 7496  burgers,frozen vegetables,eggs,french fries,ma...
# 7497                                            chicken
# 7498                                 escalope,green tea
# 7499    eggs,frozen smoothie,yogurt cake,low fat yogurt

# %%
df.shape #dimension of dataset
# Out:
# (7500, 1)

# %%
df.describe() #statistics of dataset , outlier detection
# Out:
#        shrimp,almonds,avocado,vegetables mix,green grapes,whole weat flour,yams,cottage cheese,energy drink,tomato juice,low fat yogurt,green tea,honey,salad,mineral water,salmon,antioxydant juice,frozen smoothie,spinach,olive oil
# count                                                7500
# unique                                               5175
# top                                               cookies
# freq                                                  223

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7500 entries, 0 to 7499
# Data columns (total 1 columns):
#  #   Column                                                                                                                                                                                                                           Non-Null Count  Dtype
# ---  ------                                                                                                                                                                                                                           --------------  -----
#  0   shrimp,almonds,avocado,vegetables mix,green grapes,whole weat flour,yams,cottage cheese,energy drink,tomato juice,low fat yogurt,green tea,honey,salad,mineral water,salmon,antioxydant juice,frozen smoothie,spinach,olive oil  7500 non-null   object
# dtypes: object(1)
# memory usage: 58.7+ KB

# %%
missing_values = df.isnull().sum()  # Handling the missing values

missing_values
# Out:
# shrimp,almonds,avocado,vegetables mix,green grapes,whole weat flour,yams,cottage cheese,energy drink,tomato juice,low fat yogurt,green tea,honey,salad,mineral water,salmon,antioxydant juice,frozen smoothie,spinach,olive oil    0
# dtype: int64

# %%
df = df.drop_duplicates()   # Remove the duplicates.

# %%
transaction = df.iloc[:, 0].apply(lambda x: x.split(',')) # Convert the data to a list of lists (each transaction is a list of items)

transaction
# Out:
# 0                              [burgers, meatballs, eggs]
# 1                                               [chutney]
# 2                                       [turkey, avocado]
# 3       [mineral water, milk, energy bar, whole wheat ...
# 4                                        [low fat yogurt]
#                               ...
# 7492    [burgers, salmon, pancakes, french fries, froz...
# 7493    [turkey, burgers, dessert wine, shrimp, pasta,...
# 7495                    [butter, light mayo, fresh bread]
# 7496    [burgers, frozen vegetables, eggs, french frie...
# 7499    [eggs, frozen smoothie, yogurt cake, low fat y...
# Name: shrimp,almonds,avocado,vegetables mix,green grapes,whole weat flour,yams,cottage cheese,energy drink,tomato juice,low fat yogurt,green tea,honey,salad,mineral water,salmon,antioxydant juice,frozen smoothie,spinach,olive oil, Length: 5175, dtype: object

# %%
Association Rule Mining Assignment:

-Objective: Use Python tools (like Pandas and Mlxtend) to implement the Apriori algorithm for identifying patterns in the dataset.

-Task: Apply association rule mining techniques to analyze the pre-processed dataset, aiming to uncover significant relationships between products that are frequently bought together.

-Thresholds: Set appropriate values for support, confidence, and lift to ensure the extracted rules are relevant and insightful.

# %%
# !pip install mlxtend

# %%
from mlxtend.preprocessing import TransactionEncoder
from mlxtend.frequent_patterns import apriori, association_rules
import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)

# Encode transactions into one-hot encoded format
encoder = TransactionEncoder()
transaction_matrix = encoder.fit_transform(transaction)
df_encoded = pd.DataFrame(transaction_matrix, columns=encoder.columns_)

# %%
# Importing required libraries
from mlxtend.frequent_patterns import apriori, association_rules
from mlxtend.preprocessing import TransactionEncoder
import pandas as pd
import warnings

# Suppress warnings
warnings.simplefilter(action='ignore', category=FutureWarning)

# Applying Apriori algorithm with a minimum support threshold
frequent_patterns = apriori(df_encoded, min_support=0.01, use_colnames=True)

# Print the first few rows of the frequent itemsets
print(frequent_patterns.head())
# Out:
#     support             itemsets
# 0  0.029179            (almonds)
# 1  0.011014  (antioxydant juice)
# 2  0.045797            (avocado)
# 3  0.012560              (bacon)
# 4  0.015459     (barbecue sauce)

# %%
# Generating association rules with 'lift' as the evaluation metric
assoc_rules = association_rules(frequent_patterns, metric='lift', min_threshold=1)

# Filtering the rules based on confidence and lift thresholds
filtered_rules = assoc_rules[(assoc_rules['confidence'] >= 0.5) & (assoc_rules['lift'] >= 1.2)]

# Sorting the filtered rules by lift in descending order
sorted_rules = filtered_rules.sort_values(by='lift', ascending=False)

# Display the sorted rules
sorted_rules
# Out:
#                           antecedents      consequents  antecedent support  \
# 717  (frozen vegetables, ground beef)      (spaghetti)            0.024541
# 794                      (soup, milk)  (mineral water)            0.021449
# 712  (frozen vegetables, ground beef)  (mineral water)            0.024541
# 830                 (soup, spaghetti)  (mineral water)            0.020676
# 764           (ground beef, pancakes)  (mineral water)            0.020870
# 500              (chicken, chocolate)  (mineral water)            0.021256
# 776                 (olive oil, milk)  (mineral water)            0.024155
# 600            (olive oil, chocolate)  (mineral water)            0.023575
# 752               (milk, ground beef)  (mineral water)            0.031691
# 668               (ground beef, eggs)  (mineral water)            0.028792
#
#      consequent support   support  confidence      lift  leverage  conviction  \
# ...

# %%
# OR

# Generate association rules from the frequent patterns
assoc_rules = association_rules(frequent_patterns, metric="confidence", min_threshold=0.2)

# Filtering the rules based on lift greater than 1
filtered_rules = assoc_rules[assoc_rules['lift'] > 1]

# Display the filtered rules
filtered_rules
# Out:
#                    antecedents      consequents  antecedent support  \
# 0                    (almonds)  (mineral water)            0.029179
# 1                    (avocado)      (chocolate)            0.045797
# 2                    (avocado)   (french fries)            0.045797
# 3                    (avocado)           (milk)            0.045797
# 4                    (avocado)  (mineral water)            0.045797
# ..                         ...              ...                 ...
# 350        (shrimp, spaghetti)  (mineral water)            0.030338
# 351      (mineral water, soup)      (spaghetti)            0.033430
# 352          (soup, spaghetti)  (mineral water)            0.020676
# 353  (mineral water, tomatoes)      (spaghetti)            0.034589
# 354      (tomatoes, spaghetti)  (mineral water)            0.029952
#
#      consequent support   support  confidence      lift  leverage  conviction  \
# ...

# %%
#Analysis and Interpretation:

1 - Analyzing the Generated Rules:

Key Observations from the Rules:

-Identifying Strong Rules:Focus on rules with high confidence and lift values.
 These rules highlight strong product associations that are both frequent and impactful.
Example: If there's a strong rule like "milk and bread" with high confidence and lift,
 it indicates that customers who purchase milk are much more likely to buy bread than average.

Interesting Patterns:

-Complementary Products:Some rules show how certain products are often bought together,
 suggesting they are complementary. Retailers can leverage these patterns for strategic product placement or to create bundle deals.

-Substitute Products:On the other hand, products with low lift might be substitutes,
 meaning customers tend to choose one over the other.

-High-Value Items:If certain high-value products are often linked with others,
 it can reveal opportunities for cross-selling or upselling, especially if high-margin products are involved.

Example:

-Market Basket Insights:A rule like "avocado, milk, and bread" might suggest that customers who buy avocados and milk often also buy bread.
 This insight can be used to optimize store layouts by placing these items closer together.

2 - Interpreting the Results:

Customer Buying Patterns:

- The discovered patterns provide a glimpse into customer buying preferences,
allowing retailers to better stock shelves or design promotions that cater to popular combinations of products.

Product Associations:

- By understanding the frequent pairings of products,
retailers can improve inventory management and avoid stockouts for products that are commonly bought together.

Strategic Applications:

- These insights can guide retailers in making better decisions around pricing, promotions, and product placement,
ultimately improving the shopping experience and driving sales growth.

# %%
INTERVIEW QUESTIONS FOR ASSOCIATION RULES

# %%
Here’s a more student-friendly version of the interview question and answer:

1. What is lift, and why is it important in Association Rules?

Answer:

Lift-measures how much more likely two items are to be bought together compared to if they were bought independently.
A lift value greater than 1 means the items are more strongly associated than expected by chance.

Formula:
Lift (X→Y) = Support(X∪Y) / (Support(X) × Support(Y))

1A.Why is it important?

-Understanding Relationships:Lift shows the strength of the connection between two items.
 A lift greater than 1 means that when a customer buys item X, it increases the likelihood they will also buy item Y (a positive association). If lift is less than 1, it means there’s a negative association.

-Comparison to Randomness:Lift helps us compare whether the items are frequently bought together by chance or if there's an actual connection.
 A lift of exactly 1 means the items are independent and don’t influence each other.

-Useful for Business Decisions:In retail or marketing, high lift values can help make decisions about product placement, bundling, or promotions since they highlight strong product relationships.

# %%
2. What are Support and Confidence, and how are they calculated?

Support:

-Definition:Support measures how frequently an itemset appears in the dataset.
-Formula:Support(X) = Number of transactions containing X / Total number of transactions
-Example:If "milk" is in 200 out of 1000 transactions, Support("milk") = 0.2 (20%).

Confidence:

-Definition:Confidence measures the likelihood that item Y is purchased given that item X is purchased.
-Formula:Confidence(X→Y) = Support(X∪Y) / Support(X)
-Example:If 150 out of 200 transactions with "milk" also have "bread," Confidence("milk→bread") = 0.75 (75%).

Why They Matter:

-Support helps identify frequent itemsets.
-Confidence assesses the reliability of the rule.

# %%
3. What are some limitations or challenges of Association Rules Mining?

Limitations or Challenges:

-Data Sparsity:Many itemsets may have low support, leading to sparse data and making it hard to find meaningful patterns.
-Solution:Adjust support thresholds or use dimensionality reduction techniques.

-Interpretability of Rules:A high number of rules can be overwhelming and not all will be useful or actionable.
-Solution:Use pruning techniques and additional metrics like conviction to filter meaningful rules.

-Setting Thresholds:Choosing the right thresholds for support, confidence, and lift is challenging. Too high a threshold might miss important patterns, while too low might generate too many rules.
-Solution:Experiment with different thresholds and leverage domain knowledge.

-Contextual Relevance:Rules may be context-specific, and a rule that is useful in one scenario might not be in another.
-Solution:Use contextual analysis and domain expertise to interpret and apply rules effectively.
